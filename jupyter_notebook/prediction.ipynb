# %%
# Dependencies and Setup
import pandas as pd

# %%
# Set source file path
merged_data = "../cleaned_data/cleaned_house_crime_school.csv"
predict_data = "../output/price_prediction_df.csv"

# Set output file path
merged_predict_data = "../output/predicted_cleaned_house_crime_school.csv"

# %%
df = pd.read_csv(merged_data)
df
# Out:
#            Suburb           Address  Rooms Type      Price        Date  \
# 0      Abbotsford      85 Turner St      2    h  1480000.0  2016-12-03
# 1      Abbotsford   25 Bloomburg St      2    h  1035000.0  2016-02-04
# 2      Abbotsford      5 Charles St      3    h  1465000.0  2017-03-04
# 3      Abbotsford  40 Federation La      3    h   850000.0  2017-03-04
# 4      Abbotsford       55a Park St      4    h  1600000.0  2016-06-04
# ...           ...               ...    ...  ...        ...         ...
# 16035  Yarraville     78 Bayview Rd      3    h  1101000.0  2018-02-24
# 16036  Yarraville       13 Burns St      4    h  1480000.0  2018-02-24
# 16037  Yarraville     29A Murray St      2    h   888000.0  2018-02-24
# 16038  Yarraville    147A Severn St      2    t   705000.0  2018-02-24
# 16039  Yarraville  3 Tarrengower St      2    h  1020000.0  2018-02-24
#
#        Distance  Postcode  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# ...

# %%
df=df[df["YearBuilt"]!=0]
df=df[df["BuildingArea"]!=0]
df
# Out:
#            Suburb           Address  Rooms Type      Price        Date  \
# 1      Abbotsford   25 Bloomburg St      2    h  1035000.0  2016-02-04
# 2      Abbotsford      5 Charles St      3    h  1465000.0  2017-03-04
# 4      Abbotsford       55a Park St      4    h  1600000.0  2016-06-04
# 6      Abbotsford      124 Yarra St      3    h  1876000.0  2016-05-07
# 7      Abbotsford     98 Charles St      2    h  1636000.0  2016-10-08
# ...           ...               ...    ...  ...        ...         ...
# 16032     Wollert   27 Birchmore Rd      3    h   500000.0  2018-02-24
# 16034     Wollert   35 Kingscote Wy      3    h   570000.0  2018-02-24
# 16037  Yarraville     29A Murray St      2    h   888000.0  2018-02-24
# 16038  Yarraville    147A Severn St      2    t   705000.0  2018-02-24
# 16039  Yarraville  3 Tarrengower St      2    h  1020000.0  2018-02-24
#
#        Distance  Postcode  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# ...

# %%
df = df.sort_values("Price")
df = df.reset_index(drop = True)
df = df.reset_index()
df
# Out:
#       index       Suburb             Address  Rooms Type      Price  \
# 0         0    Caulfield          30 Pyne St      4    h   131000.0
# 1         1       Coburg     171 Moreland Rd      4    h   145000.0
# 2         2    Footscray    10/30 Pickett St      1    u   170000.0
# 3         3       Albion  10/117 Anderson Rd      1    u   185000.0
# 4         4       Albion   1/121 Anderson Rd      1    u   200000.0
# ...     ...          ...                 ...    ...  ...        ...
# 7960   7960  Middle Park         136 Page St      5    h  6400000.0
# 7961   7961          Kew         15 Barry St      6    h  6500000.0
# 7962   7962     Hawthorn        49 Lisson Gr      4    h  7650000.0
# 7963   7963   Canterbury      49 Mangarra Rd      5    h  8000000.0
# 7964   7964     Mulgrave         35 Bevis St      3    h  9000000.0
#
#             Date  Distance  Postcode  Bathroom  ...  Landsize  BuildingArea  \
# ...

# %%
predict_df = pd.read_csv(predict_data)
predict_df
# Out:
#       Unnamed: 0     Actual    Prediction
# 0              0  1835000.0  1.740374e+06
# 1              1  1836000.0  1.608161e+06
# 2              2  1650000.0  1.175278e+06
# 3              3  1650000.0  1.612360e+06
# 4              4  1930000.0  1.695559e+06
# ...          ...        ...           ...
# 7959        7959   985000.0  9.900234e+05
# 7960        7960   515000.0  5.554439e+05
# 7961        7961   730000.0  7.580452e+05
# 7962        7962  1577500.0  1.514458e+06
# 7963        7963   930000.0  9.120856e+05
#
# [7964 rows x 3 columns]

# %%
predict_df = predict_df.sort_values("Actual")
predict_df = predict_df.rename({"Actual": "Price"}, axis = "columns")
predict_df = predict_df.reset_index(drop = True)
predict_df = predict_df.reset_index()
predict_df = predict_df.round({"Prediction": 2})
predict_df
# Out:
#       index  Unnamed: 0      Price  Prediction
# 0         0        7302   131000.0   692669.69
# 1         1        2032   145000.0  1183198.99
# 2         2         448   170000.0   406453.71
# 3         3        7589   185000.0   263124.06
# 4         4        4832   200000.0   280947.74
# ...     ...         ...        ...         ...
# 7959   7959        5109  6400000.0  5234946.88
# 7960   7960        2794  6500000.0  5637131.25
# 7961   7961        3873  7650000.0  6238300.31
# 7962   7962        7364  8000000.0  6535567.50
# 7963   7963         190  9000000.0   978389.18
#
# [7964 rows x 4 columns]

# %%
merged_predict_df = pd.merge(df, predict_df, on = "index")
merged_predict_df = merged_predict_df.drop(["index", "Price_x"], axis = "columns")
merged_predict_df = merged_predict_df.rename({"Price_y": "Price"}, axis = "columns")
merged_predict_df
# Out:
#            Suburb               Address  Rooms Type        Date  Distance  \
# 0       Caulfield            30 Pyne St      4    h  2017-02-25       8.9
# 1          Coburg       171 Moreland Rd      4    h  2016-06-04       7.8
# 2       Footscray      10/30 Pickett St      1    u  2017-07-01       5.1
# 3          Albion    10/117 Anderson Rd      1    u  2016-08-22      13.9
# 4          Albion     1/121 Anderson Rd      1    u  2017-05-20      13.9
# ...           ...                   ...    ...  ...         ...       ...
# 7959  Middle Park  307 Beaconsfield Pde      4    h  2017-10-14       3.0
# 7960  Middle Park           136 Page St      5    h  2017-09-09       3.0
# 7961          Kew           15 Barry St      6    h  2016-08-13       5.6
# 7962     Hawthorn          49 Lisson Gr      4    h  2017-06-17       5.3
# 7963   Canterbury        49 Mangarra Rd      5    h  2017-05-13       9.0
#
#       Postcode  Bathroom  Car  Landsize  ...                CouncilArea  \
# ...

# %%
merged_predict_df.to_csv("../output/merged_prediction.csv", index = False, encoding = "utf-8")
