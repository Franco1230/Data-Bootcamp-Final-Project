# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read the CSV
df = pd.read_csv("../cleaned_data/cleaned_house_crime_school.csv")
df
# Out:
#            Suburb           Address  Rooms Type      Price        Date  \
# 0      Abbotsford      85 Turner St      2    h  1480000.0  2016-12-03
# 1      Abbotsford   25 Bloomburg St      2    h  1035000.0  2016-02-04
# 2      Abbotsford      5 Charles St      3    h  1465000.0  2017-03-04
# 3      Abbotsford  40 Federation La      3    h   850000.0  2017-03-04
# 4      Abbotsford       55a Park St      4    h  1600000.0  2016-06-04
# ...           ...               ...    ...  ...        ...         ...
# 16035  Yarraville     78 Bayview Rd      3    h  1101000.0  2018-02-24
# 16036  Yarraville       13 Burns St      4    h  1480000.0  2018-02-24
# 16037  Yarraville     29A Murray St      2    h   888000.0  2018-02-24
# 16038  Yarraville    147A Severn St      2    t   705000.0  2018-02-24
# 16039  Yarraville  3 Tarrengower St      2    h  1020000.0  2018-02-24
#
#        Distance  Postcode  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0           2.5      3067         1    1       202             0          0
# 1           2.5      3067         1    0       156            79       1900
# 2           2.5      3067         2    0       134           150       1900
# 3           2.5      3067         2    1        94             0          0
# 4           2.5      3067         1    2       120           142       2014
# ...         ...       ...       ...  ...       ...           ...        ...
# 16035       6.3      3013         1    0       288             0          0
# 16036       6.3      3013         1    3       593             0          0
# 16037       6.3      3013         2    1        98           104       2018
# 16038       6.3      3013         1    2       220           120       2000
# 16039       6.3      3013         1    0       250           103       1930
#
#                     CouncilArea  Lattitude  Longtitude             Regionname  \
# 0            Yarra City Council   -37.7996    144.9984  Northern Metropolitan
# 1            Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 2            Yarra City Council   -37.8093    144.9944  Northern Metropolitan
# 3            Yarra City Council   -37.7969    144.9969  Northern Metropolitan
# 4            Yarra City Council   -37.8072    144.9941  Northern Metropolitan
# ...                         ...        ...         ...                    ...
# 16035  Maribyrnong City Council   -37.8110    144.8852   Western Metropolitan
# 16036  Maribyrnong City Council   -37.8105    144.8847   Western Metropolitan
# 16037  Maribyrnong City Council   -37.8155    144.8883   Western Metropolitan
# 16038  Maribyrnong City Council   -37.8229    144.8786   Western Metropolitan
# 16039  Maribyrnong City Council   -37.8181    144.8935   Western Metropolitan
#
#        Propertycount  CrimeRate  NearbySchools
# 0               4019        157              2
# 1               4019        157              2
# 2               4019        157              2
# 3               4019        157              2
# 4               4019        157              2
# ...              ...        ...            ...
# 16035           6543        136              5
# 16036           6543        136              5
# 16037           6543        136              5
# 16038           6543        136              5
# 16039           6543        136              5
#
# [16040 rows x 20 columns]

# %% [markdown]
# # Select features (columns)

# %%
# Set features to be used as X values.
X = df.drop(["Price", "Suburb", "Date", "Address", "Type", "Postcode", "CouncilArea", "Lattitude", "Longtitude", "Regionname", "YearBuilt", "Distance", "CrimeRate"], axis = "columns")
y = df["Price"]
print(X.shape, y.shape)
# Out:
# (16040, 7) (16040,)

# %%
X
# Out:
#        Rooms  Bathroom  Car  Landsize  BuildingArea  Propertycount  \
# 0          2         1    1       202             0           4019
# 1          2         1    0       156            79           4019
# 2          3         2    0       134           150           4019
# 3          3         2    1        94             0           4019
# 4          4         1    2       120           142           4019
# ...      ...       ...  ...       ...           ...            ...
# 16035      3         1    0       288             0           6543
# 16036      4         1    3       593             0           6543
# 16037      2         2    1        98           104           6543
# 16038      2         1    2       220           120           6543
# 16039      2         1    0       250           103           6543
#
#        NearbySchools
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# ...              ...
# 16035              5
# 16036              5
# 16037              5
# 16038              5
# 16039              5
#
# [16040 rows x 7 columns]

# %%
# GET housing stats
total_houses = len(df)
max_value = df["Price"].describe()["max"]
min_value = df["Price"].describe()["min"]
print(f"Total houses: {total_houses}")
print(f"Highest price: {max_value}")
print(f"Lowest price: {min_value}")
# Out:
# Total houses: 16040
# Highest price: 11200000.0
# Lowest price: 131000.0

# %% [markdown]
# # Split the data into test and train data using `train_test_split` with test size of 33%

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.33)
X_train
# Out:
#        Rooms  Bathroom  Car  Landsize  BuildingArea  Propertycount  \
# 6367       3         2    2       226           140           3593
# 14911      5         2    3       635             0           3619
# 1597       3         1    2       699             0           5051
# 10351      3         2    1      1007           250           2985
# 6765       3         2    2       257           120          21650
# ...      ...       ...  ...       ...           ...            ...
# 13418      3         2    4       560           154           7630
# 5390       3         1    1       202             0           6543
# 860        2         1    2       750             0          10969
# 15795      5         2    2       710             0           2671
# 7270       3         1    3       758             0           5498
#
#        NearbySchools
# 6367               7
# 14911             12
# 1597               4
# 10351             13
# 6765              14
# ...              ...
# 13418              8
# 5390               5
# 860                7
# 15795              3
# 7270               6
#
# [10746 rows x 7 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale X values
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
y_train = y_train.array.reshape(-1, 1)

# %%
# Label Encode the target feature from human words to machine id's
label_encoder = OrdinalEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
#encoded_y_test = label_encoder.transform(y_test)

y_train_categorical = to_categorical(encoded_y_train)
#y_test_categorical = to_categorical(encoded_y_test)

# %%
print(X_train_scaled.shape, y_train_categorical.shape)
# Out:
# (10746, 7) (10746, 1997)

# %% [markdown]
# # Tune Model Parameters

# %%
# Create the model and the layers
model = Sequential()
model.add(Dense(units = 50, activation = "relu", input_dim = X_train_scaled.shape[1]))
model.add(Dense(units = 100, activation = "relu"))
model.add(Dense(units = 150, activation = "relu"))
model.add(Dense(units = 200, activation = "relu"))
model.add(Dense(units = y_train_categorical.shape[1], activation = "softmax"))

# %%
# Compile the model
model.compile(optimizer = "adam",
              loss = "categorical_crossentropy",
              metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                400
#
#  dense_1 (Dense)             (None, 100)               5100
#
#  dense_2 (Dense)             (None, 150)               15150
#
#  dense_3 (Dense)             (None, 200)               30200
#
#  dense_4 (Dense)             (None, 1997)              401397
#
# =================================================================
# Total params: 452,247
# Trainable params: 452,247
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train Tuned Model

# %%
model.fit(X_train_scaled,
          y_train_categorical,
          epochs = 500,
          shuffle = True,
          verbose = 2)
# Out:
# Epoch 1/500
# 336/336 - 4s - loss: 7.0330 - accuracy: 0.0075 - 4s/epoch - 11ms/step
# Epoch 2/500
# 336/336 - 3s - loss: 6.7446 - accuracy: 0.0085 - 3s/epoch - 9ms/step
# Epoch 3/500
# 336/336 - 3s - loss: 6.6520 - accuracy: 0.0110 - 3s/epoch - 9ms/step
# Epoch 4/500
# 336/336 - 3s - loss: 6.5390 - accuracy: 0.0133 - 3s/epoch - 9ms/step
# Epoch 5/500
# 336/336 - 3s - loss: 6.4637 - accuracy: 0.0126 - 3s/epoch - 9ms/step
# Epoch 6/500
# 336/336 - 3s - loss: 6.4084 - accuracy: 0.0132 - 3s/epoch - 8ms/step
# Epoch 7/500
# 336/336 - 3s - loss: 6.3645 - accuracy: 0.0129 - 3s/epoch - 8ms/step
# Epoch 8/500
# 336/336 - 3s - loss: 6.3230 - accuracy: 0.0144 - 3s/epoch - 9ms/step
# Epoch 9/500
# 336/336 - 3s - loss: 6.2767 - accuracy: 0.0150 - 3s/epoch - 8ms/step
# Epoch 10/500
# 336/336 - 3s - loss: 6.2262 - accuracy: 0.0146 - 3s/epoch - 8ms/step
# Epoch 11/500
# 336/336 - 3s - loss: 6.1719 - accuracy: 0.0141 - 3s/epoch - 8ms/step
# Epoch 12/500
# 336/336 - 3s - loss: 6.1116 - accuracy: 0.0151 - 3s/epoch - 8ms/step
# Epoch 13/500
# 336/336 - 3s - loss: 6.0480 - accuracy: 0.0160 - 3s/epoch - 8ms/step
# Epoch 14/500
# 336/336 - 2s - loss: 5.9832 - accuracy: 0.0163 - 2s/epoch - 7ms/step
# Epoch 15/500
# 336/336 - 3s - loss: 5.9131 - accuracy: 0.0162 - 3s/epoch - 8ms/step
# Epoch 16/500
# 336/336 - 3s - loss: 5.8301 - accuracy: 0.0161 - 3s/epoch - 7ms/step
# Epoch 17/500
# 336/336 - 2s - loss: 5.7513 - accuracy: 0.0155 - 2s/epoch - 7ms/step
# Epoch 18/500
# 336/336 - 3s - loss: 5.6708 - accuracy: 0.0152 - 3s/epoch - 8ms/step
# Epoch 19/500
# 336/336 - 3s - loss: 5.5896 - accuracy: 0.0158 - 3s/epoch - 7ms/step
# Epoch 20/500
# 336/336 - 3s - loss: 5.5123 - accuracy: 0.0192 - 3s/epoch - 8ms/step
# Epoch 21/500
# 336/336 - 3s - loss: 5.4392 - accuracy: 0.0189 - 3s/epoch - 8ms/step
# Epoch 22/500
# 336/336 - 3s - loss: 5.3628 - accuracy: 0.0195 - 3s/epoch - 8ms/step
# Epoch 23/500
# 336/336 - 2s - loss: 5.2932 - accuracy: 0.0214 - 2s/epoch - 7ms/step
# Epoch 24/500
# 336/336 - 2s - loss: 5.2232 - accuracy: 0.0232 - 2s/epoch - 7ms/step
# Epoch 25/500
# 336/336 - 2s - loss: 5.1565 - accuracy: 0.0245 - 2s/epoch - 7ms/step
# Epoch 26/500
# 336/336 - 2s - loss: 5.0952 - accuracy: 0.0275 - 2s/epoch - 7ms/step
# Epoch 27/500
# 336/336 - 3s - loss: 5.0308 - accuracy: 0.0285 - 3s/epoch - 8ms/step
# Epoch 28/500
# 336/336 - 3s - loss: 4.9664 - accuracy: 0.0342 - 3s/epoch - 8ms/step
# Epoch 29/500
# 336/336 - 2s - loss: 4.9123 - accuracy: 0.0342 - 2s/epoch - 7ms/step
# Epoch 30/500
# 336/336 - 2s - loss: 4.8570 - accuracy: 0.0402 - 2s/epoch - 7ms/step
# Epoch 31/500
# 336/336 - 2s - loss: 4.8035 - accuracy: 0.0428 - 2s/epoch - 7ms/step
# Epoch 32/500
# 336/336 - 2s - loss: 4.7508 - accuracy: 0.0481 - 2s/epoch - 7ms/step
# Epoch 33/500
# 336/336 - 2s - loss: 4.7061 - accuracy: 0.0496 - 2s/epoch - 7ms/step
# Epoch 34/500
# 336/336 - 3s - loss: 4.6650 - accuracy: 0.0505 - 3s/epoch - 7ms/step
# Epoch 35/500
# 336/336 - 2s - loss: 4.6240 - accuracy: 0.0531 - 2s/epoch - 7ms/step
# Epoch 36/500
# 336/336 - 3s - loss: 4.5833 - accuracy: 0.0584 - 3s/epoch - 7ms/step
# Epoch 37/500
# 336/336 - 3s - loss: 4.5428 - accuracy: 0.0577 - 3s/epoch - 8ms/step
# Epoch 38/500
# 336/336 - 3s - loss: 4.5070 - accuracy: 0.0626 - 3s/epoch - 8ms/step
# Epoch 39/500
# 336/336 - 3s - loss: 4.4674 - accuracy: 0.0643 - 3s/epoch - 8ms/step
# Epoch 40/500
# 336/336 - 3s - loss: 4.4300 - accuracy: 0.0683 - 3s/epoch - 7ms/step
# Epoch 41/500
# 336/336 - 3s - loss: 4.4042 - accuracy: 0.0668 - 3s/epoch - 7ms/step
# Epoch 42/500
# 336/336 - 3s - loss: 4.3719 - accuracy: 0.0730 - 3s/epoch - 8ms/step
# Epoch 43/500
# 336/336 - 3s - loss: 4.3477 - accuracy: 0.0731 - 3s/epoch - 8ms/step
# Epoch 44/500
# 336/336 - 3s - loss: 4.3177 - accuracy: 0.0758 - 3s/epoch - 9ms/step
# Epoch 45/500
# 336/336 - 3s - loss: 4.2970 - accuracy: 0.0792 - 3s/epoch - 8ms/step
# Epoch 46/500
# 336/336 - 3s - loss: 4.2644 - accuracy: 0.0804 - 3s/epoch - 8ms/step
# Epoch 47/500
# 336/336 - 3s - loss: 4.2432 - accuracy: 0.0844 - 3s/epoch - 8ms/step
# Epoch 48/500
# 336/336 - 2s - loss: 4.2163 - accuracy: 0.0845 - 2s/epoch - 7ms/step
# Epoch 49/500
# 336/336 - 2s - loss: 4.1903 - accuracy: 0.0866 - 2s/epoch - 7ms/step
# Epoch 50/500
# 336/336 - 2s - loss: 4.1714 - accuracy: 0.0889 - 2s/epoch - 7ms/step
# Epoch 51/500
# 336/336 - 2s - loss: 4.1484 - accuracy: 0.0853 - 2s/epoch - 7ms/step
# Epoch 52/500
# 336/336 - 2s - loss: 4.1282 - accuracy: 0.0921 - 2s/epoch - 7ms/step
# Epoch 53/500
# 336/336 - 3s - loss: 4.1127 - accuracy: 0.0907 - 3s/epoch - 8ms/step
# Epoch 54/500
# 336/336 - 3s - loss: 4.0822 - accuracy: 0.0932 - 3s/epoch - 8ms/step
# Epoch 55/500
# 336/336 - 3s - loss: 4.0643 - accuracy: 0.0965 - 3s/epoch - 7ms/step
# Epoch 56/500
# 336/336 - 2s - loss: 4.0541 - accuracy: 0.0971 - 2s/epoch - 7ms/step
# Epoch 57/500
# 336/336 - 3s - loss: 4.0304 - accuracy: 0.0992 - 3s/epoch - 8ms/step
# Epoch 58/500
# 336/336 - 2s - loss: 4.0233 - accuracy: 0.1012 - 2s/epoch - 7ms/step
# Epoch 59/500
# 336/336 - 2s - loss: 3.9955 - accuracy: 0.1025 - 2s/epoch - 7ms/step
# Epoch 60/500
# 336/336 - 3s - loss: 3.9836 - accuracy: 0.1034 - 3s/epoch - 8ms/step
# Epoch 61/500
# 336/336 - 2s - loss: 3.9720 - accuracy: 0.1012 - 2s/epoch - 7ms/step
# Epoch 62/500
# 336/336 - 2s - loss: 3.9503 - accuracy: 0.1031 - 2s/epoch - 7ms/step
# Epoch 63/500
# 336/336 - 3s - loss: 3.9361 - accuracy: 0.1078 - 3s/epoch - 8ms/step
# Epoch 64/500
# 336/336 - 2s - loss: 3.9270 - accuracy: 0.1105 - 2s/epoch - 7ms/step
# Epoch 65/500
# 336/336 - 2s - loss: 3.9030 - accuracy: 0.1111 - 2s/epoch - 7ms/step
# Epoch 66/500
# 336/336 - 2s - loss: 3.8914 - accuracy: 0.1124 - 2s/epoch - 7ms/step
# Epoch 67/500
# 336/336 - 2s - loss: 3.8809 - accuracy: 0.1132 - 2s/epoch - 7ms/step
# Epoch 68/500
# 336/336 - 3s - loss: 3.8718 - accuracy: 0.1131 - 3s/epoch - 8ms/step
# Epoch 69/500
# 336/336 - 3s - loss: 3.8419 - accuracy: 0.1180 - 3s/epoch - 8ms/step
# Epoch 70/500
# 336/336 - 2s - loss: 3.8453 - accuracy: 0.1172 - 2s/epoch - 7ms/step
# Epoch 71/500
# 336/336 - 2s - loss: 3.8258 - accuracy: 0.1170 - 2s/epoch - 7ms/step
# Epoch 72/500
# 336/336 - 3s - loss: 3.8225 - accuracy: 0.1177 - 3s/epoch - 7ms/step
# Epoch 73/500
# 336/336 - 2s - loss: 3.7941 - accuracy: 0.1184 - 2s/epoch - 7ms/step
# Epoch 74/500
# 336/336 - 2s - loss: 3.8008 - accuracy: 0.1204 - 2s/epoch - 7ms/step
# Epoch 75/500
# 336/336 - 3s - loss: 3.7856 - accuracy: 0.1218 - 3s/epoch - 8ms/step
# Epoch 76/500
# 336/336 - 3s - loss: 3.7744 - accuracy: 0.1224 - 3s/epoch - 7ms/step
# Epoch 77/500
# 336/336 - 3s - loss: 3.7601 - accuracy: 0.1229 - 3s/epoch - 8ms/step
# Epoch 78/500
# 336/336 - 2s - loss: 3.7384 - accuracy: 0.1268 - 2s/epoch - 7ms/step
# Epoch 79/500
# 336/336 - 3s - loss: 3.7334 - accuracy: 0.1227 - 3s/epoch - 8ms/step
# Epoch 80/500
# 336/336 - 3s - loss: 3.7260 - accuracy: 0.1248 - 3s/epoch - 8ms/step
# Epoch 81/500
# 336/336 - 3s - loss: 3.7260 - accuracy: 0.1263 - 3s/epoch - 8ms/step
# Epoch 82/500
# 336/336 - 3s - loss: 3.7068 - accuracy: 0.1342 - 3s/epoch - 8ms/step
# Epoch 83/500
# 336/336 - 3s - loss: 3.7010 - accuracy: 0.1317 - 3s/epoch - 8ms/step
# Epoch 84/500
# 336/336 - 2s - loss: 3.6761 - accuracy: 0.1330 - 2s/epoch - 7ms/step
# Epoch 85/500
# 336/336 - 2s - loss: 3.6847 - accuracy: 0.1294 - 2s/epoch - 7ms/step
# Epoch 86/500
# 336/336 - 3s - loss: 3.6605 - accuracy: 0.1334 - 3s/epoch - 7ms/step
# Epoch 87/500
# 336/336 - 2s - loss: 3.6519 - accuracy: 0.1336 - 2s/epoch - 7ms/step
# Epoch 88/500
# 336/336 - 3s - loss: 3.6504 - accuracy: 0.1326 - 3s/epoch - 8ms/step
# Epoch 89/500
# 336/336 - 3s - loss: 3.6359 - accuracy: 0.1355 - 3s/epoch - 9ms/step
# Epoch 90/500
# 336/336 - 3s - loss: 3.6346 - accuracy: 0.1367 - 3s/epoch - 9ms/step
# Epoch 91/500
# 336/336 - 3s - loss: 3.6170 - accuracy: 0.1384 - 3s/epoch - 8ms/step
# Epoch 92/500
# 336/336 - 3s - loss: 3.5952 - accuracy: 0.1429 - 3s/epoch - 8ms/step
# Epoch 93/500
# 336/336 - 3s - loss: 3.6004 - accuracy: 0.1372 - 3s/epoch - 8ms/step
# Epoch 94/500
# 336/336 - 3s - loss: 3.5936 - accuracy: 0.1381 - 3s/epoch - 8ms/step
# Epoch 95/500
# 336/336 - 3s - loss: 3.5863 - accuracy: 0.1441 - 3s/epoch - 8ms/step
# Epoch 96/500
# 336/336 - 3s - loss: 3.5778 - accuracy: 0.1430 - 3s/epoch - 8ms/step
# Epoch 97/500
# 336/336 - 3s - loss: 3.5581 - accuracy: 0.1453 - 3s/epoch - 8ms/step
# Epoch 98/500
# 336/336 - 3s - loss: 3.5630 - accuracy: 0.1446 - 3s/epoch - 8ms/step
# Epoch 99/500
# 336/336 - 3s - loss: 3.5533 - accuracy: 0.1459 - 3s/epoch - 8ms/step
# Epoch 100/500
# 336/336 - 3s - loss: 3.5450 - accuracy: 0.1459 - 3s/epoch - 8ms/step
# Epoch 101/500
# 336/336 - 3s - loss: 3.5206 - accuracy: 0.1500 - 3s/epoch - 8ms/step
# Epoch 102/500
# 336/336 - 3s - loss: 3.5112 - accuracy: 0.1508 - 3s/epoch - 8ms/step
# Epoch 103/500
# 336/336 - 3s - loss: 3.5104 - accuracy: 0.1502 - 3s/epoch - 8ms/step
# Epoch 104/500
# 336/336 - 3s - loss: 3.5027 - accuracy: 0.1508 - 3s/epoch - 9ms/step
# Epoch 105/500
# 336/336 - 3s - loss: 3.5008 - accuracy: 0.1515 - 3s/epoch - 9ms/step
# Epoch 106/500
# 336/336 - 3s - loss: 3.4958 - accuracy: 0.1520 - 3s/epoch - 8ms/step
# Epoch 107/500
# 336/336 - 3s - loss: 3.4890 - accuracy: 0.1562 - 3s/epoch - 8ms/step
# Epoch 108/500
# 336/336 - 3s - loss: 3.4806 - accuracy: 0.1530 - 3s/epoch - 8ms/step
# Epoch 109/500
# 336/336 - 3s - loss: 3.4598 - accuracy: 0.1580 - 3s/epoch - 8ms/step
# Epoch 110/500
# 336/336 - 3s - loss: 3.4708 - accuracy: 0.1531 - 3s/epoch - 8ms/step
# Epoch 111/500
# 336/336 - 3s - loss: 3.4579 - accuracy: 0.1536 - 3s/epoch - 8ms/step
# Epoch 112/500
# 336/336 - 3s - loss: 3.4499 - accuracy: 0.1531 - 3s/epoch - 8ms/step
# Epoch 113/500
# 336/336 - 3s - loss: 3.4315 - accuracy: 0.1586 - 3s/epoch - 8ms/step
# Epoch 114/500
# 336/336 - 3s - loss: 3.4251 - accuracy: 0.1615 - 3s/epoch - 8ms/step
# Epoch 115/500
# 336/336 - 3s - loss: 3.4439 - accuracy: 0.1564 - 3s/epoch - 8ms/step
# Epoch 116/500
# 336/336 - 3s - loss: 3.4167 - accuracy: 0.1569 - 3s/epoch - 9ms/step
# Epoch 117/500
# 336/336 - 3s - loss: 3.3999 - accuracy: 0.1614 - 3s/epoch - 9ms/step
# Epoch 118/500
# 336/336 - 4s - loss: 3.4059 - accuracy: 0.1608 - 4s/epoch - 11ms/step
# Epoch 119/500
# 336/336 - 4s - loss: 3.3919 - accuracy: 0.1669 - 4s/epoch - 11ms/step
# Epoch 120/500
# 336/336 - 3s - loss: 3.3813 - accuracy: 0.1658 - 3s/epoch - 10ms/step
# Epoch 121/500
# 336/336 - 3s - loss: 3.3916 - accuracy: 0.1623 - 3s/epoch - 10ms/step
# Epoch 122/500
# 336/336 - 3s - loss: 3.3679 - accuracy: 0.1664 - 3s/epoch - 9ms/step
# Epoch 123/500
# 336/336 - 3s - loss: 3.3646 - accuracy: 0.1683 - 3s/epoch - 8ms/step
# Epoch 124/500
# 336/336 - 3s - loss: 3.3629 - accuracy: 0.1679 - 3s/epoch - 8ms/step
# Epoch 125/500
# 336/336 - 3s - loss: 3.3529 - accuracy: 0.1666 - 3s/epoch - 9ms/step
# Epoch 126/500
# 336/336 - 3s - loss: 3.3499 - accuracy: 0.1722 - 3s/epoch - 10ms/step
# Epoch 127/500
# 336/336 - 3s - loss: 3.3479 - accuracy: 0.1728 - 3s/epoch - 10ms/step
# Epoch 128/500
# 336/336 - 3s - loss: 3.3409 - accuracy: 0.1728 - 3s/epoch - 9ms/step
# Epoch 129/500
# 336/336 - 3s - loss: 3.3317 - accuracy: 0.1721 - 3s/epoch - 9ms/step
# Epoch 130/500
# 336/336 - 3s - loss: 3.3152 - accuracy: 0.1724 - 3s/epoch - 8ms/step
# Epoch 131/500
# 336/336 - 3s - loss: 3.3167 - accuracy: 0.1774 - 3s/epoch - 9ms/step
# Epoch 132/500
# 336/336 - 3s - loss: 3.3074 - accuracy: 0.1724 - 3s/epoch - 9ms/step
# Epoch 133/500
# 336/336 - 3s - loss: 3.3050 - accuracy: 0.1732 - 3s/epoch - 8ms/step
# Epoch 134/500
# 336/336 - 3s - loss: 3.2962 - accuracy: 0.1764 - 3s/epoch - 8ms/step
# Epoch 135/500
# 336/336 - 3s - loss: 3.3065 - accuracy: 0.1721 - 3s/epoch - 8ms/step
# Epoch 136/500
# 336/336 - 3s - loss: 3.2945 - accuracy: 0.1769 - 3s/epoch - 8ms/step
# Epoch 137/500
# 336/336 - 3s - loss: 3.2804 - accuracy: 0.1773 - 3s/epoch - 8ms/step
# Epoch 138/500
# 336/336 - 3s - loss: 3.2714 - accuracy: 0.1775 - 3s/epoch - 9ms/step
# Epoch 139/500
# 336/336 - 3s - loss: 3.2608 - accuracy: 0.1846 - 3s/epoch - 8ms/step
# Epoch 140/500
# 336/336 - 3s - loss: 3.2633 - accuracy: 0.1788 - 3s/epoch - 9ms/step
# Epoch 141/500
# 336/336 - 3s - loss: 3.2678 - accuracy: 0.1833 - 3s/epoch - 9ms/step
# Epoch 142/500
# 336/336 - 3s - loss: 3.2492 - accuracy: 0.1837 - 3s/epoch - 10ms/step
# Epoch 143/500
# 336/336 - 3s - loss: 3.2480 - accuracy: 0.1854 - 3s/epoch - 9ms/step
# Epoch 144/500
# 336/336 - 3s - loss: 3.2471 - accuracy: 0.1831 - 3s/epoch - 8ms/step
# Epoch 145/500
# 336/336 - 3s - loss: 3.2364 - accuracy: 0.1819 - 3s/epoch - 8ms/step
# Epoch 146/500
# 336/336 - 3s - loss: 3.2180 - accuracy: 0.1868 - 3s/epoch - 8ms/step
# Epoch 147/500
# 336/336 - 3s - loss: 3.2238 - accuracy: 0.1858 - 3s/epoch - 8ms/step
# Epoch 148/500
# 336/336 - 3s - loss: 3.2136 - accuracy: 0.1891 - 3s/epoch - 8ms/step
# Epoch 149/500
# 336/336 - 3s - loss: 3.2097 - accuracy: 0.1890 - 3s/epoch - 9ms/step
# Epoch 150/500
# 336/336 - 3s - loss: 3.2368 - accuracy: 0.1887 - 3s/epoch - 8ms/step
# Epoch 151/500
# 336/336 - 3s - loss: 3.2008 - accuracy: 0.1919 - 3s/epoch - 8ms/step
# Epoch 152/500
# 336/336 - 3s - loss: 3.2005 - accuracy: 0.1885 - 3s/epoch - 8ms/step
# Epoch 153/500
# 336/336 - 3s - loss: 3.2015 - accuracy: 0.1883 - 3s/epoch - 8ms/step
# Epoch 154/500
# 336/336 - 3s - loss: 3.2067 - accuracy: 0.1895 - 3s/epoch - 8ms/step
# Epoch 155/500
# 336/336 - 3s - loss: 3.1850 - accuracy: 0.1948 - 3s/epoch - 9ms/step
# Epoch 156/500
# 336/336 - 3s - loss: 3.1672 - accuracy: 0.1943 - 3s/epoch - 9ms/step
# Epoch 157/500
# 336/336 - 3s - loss: 3.1810 - accuracy: 0.1933 - 3s/epoch - 10ms/step
# Epoch 158/500
# 336/336 - 4s - loss: 3.1719 - accuracy: 0.1953 - 4s/epoch - 11ms/step
# Epoch 159/500
# 336/336 - 3s - loss: 3.1612 - accuracy: 0.1963 - 3s/epoch - 9ms/step
# Epoch 160/500
# 336/336 - 3s - loss: 3.1556 - accuracy: 0.1937 - 3s/epoch - 9ms/step
# Epoch 161/500
# 336/336 - 3s - loss: 3.1700 - accuracy: 0.1946 - 3s/epoch - 9ms/step
# Epoch 162/500
# 336/336 - 3s - loss: 3.1530 - accuracy: 0.1992 - 3s/epoch - 8ms/step
# Epoch 163/500
# 336/336 - 3s - loss: 3.1468 - accuracy: 0.2012 - 3s/epoch - 8ms/step
# Epoch 164/500
# 336/336 - 3s - loss: 3.1458 - accuracy: 0.2009 - 3s/epoch - 8ms/step
# Epoch 165/500
# 336/336 - 3s - loss: 3.1398 - accuracy: 0.1992 - 3s/epoch - 8ms/step
# Epoch 166/500
# 336/336 - 3s - loss: 3.1262 - accuracy: 0.1995 - 3s/epoch - 9ms/step
# Epoch 167/500
# 336/336 - 3s - loss: 3.1225 - accuracy: 0.2014 - 3s/epoch - 9ms/step
# Epoch 168/500
# 336/336 - 3s - loss: 3.1128 - accuracy: 0.2046 - 3s/epoch - 8ms/step
# Epoch 169/500
# 336/336 - 3s - loss: 3.1228 - accuracy: 0.2014 - 3s/epoch - 8ms/step
# Epoch 170/500
# 336/336 - 3s - loss: 3.1164 - accuracy: 0.2021 - 3s/epoch - 8ms/step
# Epoch 171/500
# 336/336 - 3s - loss: 3.1118 - accuracy: 0.2044 - 3s/epoch - 8ms/step
# Epoch 172/500
# 336/336 - 3s - loss: 3.1001 - accuracy: 0.2027 - 3s/epoch - 8ms/step
# Epoch 173/500
# 336/336 - 3s - loss: 3.1025 - accuracy: 0.2044 - 3s/epoch - 8ms/step
# Epoch 174/500
# 336/336 - 3s - loss: 3.0902 - accuracy: 0.2037 - 3s/epoch - 8ms/step
# Epoch 175/500
# 336/336 - 3s - loss: 3.0820 - accuracy: 0.2077 - 3s/epoch - 8ms/step
# Epoch 176/500
# 336/336 - 3s - loss: 3.0773 - accuracy: 0.2111 - 3s/epoch - 8ms/step
# Epoch 177/500
# 336/336 - 3s - loss: 3.0996 - accuracy: 0.2031 - 3s/epoch - 8ms/step
# Epoch 178/500
# 336/336 - 3s - loss: 3.0798 - accuracy: 0.2073 - 3s/epoch - 8ms/step
# Epoch 179/500
# 336/336 - 3s - loss: 3.0699 - accuracy: 0.2088 - 3s/epoch - 8ms/step
# Epoch 180/500
# 336/336 - 3s - loss: 3.0676 - accuracy: 0.2097 - 3s/epoch - 8ms/step
# Epoch 181/500
# 336/336 - 3s - loss: 3.0527 - accuracy: 0.2114 - 3s/epoch - 8ms/step
# Epoch 182/500
# 336/336 - 3s - loss: 3.0618 - accuracy: 0.2103 - 3s/epoch - 9ms/step
# Epoch 183/500
# 336/336 - 3s - loss: 3.0554 - accuracy: 0.2087 - 3s/epoch - 8ms/step
# Epoch 184/500
# 336/336 - 3s - loss: 3.0560 - accuracy: 0.2108 - 3s/epoch - 8ms/step
# Epoch 185/500
# 336/336 - 3s - loss: 3.0442 - accuracy: 0.2128 - 3s/epoch - 8ms/step
# Epoch 186/500
# 336/336 - 3s - loss: 3.0416 - accuracy: 0.2125 - 3s/epoch - 8ms/step
# Epoch 187/500
# 336/336 - 3s - loss: 3.0325 - accuracy: 0.2109 - 3s/epoch - 8ms/step
# Epoch 188/500
# 336/336 - 3s - loss: 3.0311 - accuracy: 0.2146 - 3s/epoch - 8ms/step
# Epoch 189/500
# 336/336 - 3s - loss: 3.0383 - accuracy: 0.2098 - 3s/epoch - 8ms/step
# Epoch 190/500
# 336/336 - 3s - loss: 3.0279 - accuracy: 0.2104 - 3s/epoch - 8ms/step
# Epoch 191/500
# 336/336 - 3s - loss: 3.0208 - accuracy: 0.2212 - 3s/epoch - 9ms/step
# Epoch 192/500
# 336/336 - 3s - loss: 3.0247 - accuracy: 0.2146 - 3s/epoch - 9ms/step
# Epoch 193/500
# 336/336 - 3s - loss: 3.0060 - accuracy: 0.2196 - 3s/epoch - 8ms/step
# Epoch 194/500
# 336/336 - 3s - loss: 2.9955 - accuracy: 0.2226 - 3s/epoch - 8ms/step
# Epoch 195/500
# 336/336 - 3s - loss: 3.0190 - accuracy: 0.2181 - 3s/epoch - 9ms/step
# Epoch 196/500
# 336/336 - 3s - loss: 2.9936 - accuracy: 0.2220 - 3s/epoch - 9ms/step
# Epoch 197/500
# 336/336 - 3s - loss: 3.0345 - accuracy: 0.2096 - 3s/epoch - 9ms/step
# Epoch 198/500
# 336/336 - 3s - loss: 2.9850 - accuracy: 0.2253 - 3s/epoch - 8ms/step
# Epoch 199/500
# 336/336 - 3s - loss: 2.9827 - accuracy: 0.2212 - 3s/epoch - 8ms/step
# Epoch 200/500
# 336/336 - 3s - loss: 2.9945 - accuracy: 0.2214 - 3s/epoch - 8ms/step
# Epoch 201/500
# 336/336 - 3s - loss: 2.9822 - accuracy: 0.2160 - 3s/epoch - 8ms/step
# Epoch 202/500
# 336/336 - 3s - loss: 2.9680 - accuracy: 0.2230 - 3s/epoch - 8ms/step
# Epoch 203/500
# 336/336 - 3s - loss: 2.9864 - accuracy: 0.2224 - 3s/epoch - 8ms/step
# Epoch 204/500
# 336/336 - 3s - loss: 2.9677 - accuracy: 0.2237 - 3s/epoch - 8ms/step
# Epoch 205/500
# 336/336 - 3s - loss: 2.9782 - accuracy: 0.2222 - 3s/epoch - 8ms/step
# Epoch 206/500
# 336/336 - 3s - loss: 2.9577 - accuracy: 0.2252 - 3s/epoch - 8ms/step
# Epoch 207/500
# 336/336 - 3s - loss: 2.9782 - accuracy: 0.2206 - 3s/epoch - 8ms/step
# Epoch 208/500
# 336/336 - 3s - loss: 2.9476 - accuracy: 0.2269 - 3s/epoch - 8ms/step
# Epoch 209/500
# 336/336 - 3s - loss: 2.9524 - accuracy: 0.2302 - 3s/epoch - 8ms/step
# Epoch 210/500
# 336/336 - 3s - loss: 2.9606 - accuracy: 0.2227 - 3s/epoch - 8ms/step
# Epoch 211/500
# 336/336 - 3s - loss: 2.9518 - accuracy: 0.2247 - 3s/epoch - 8ms/step
# Epoch 212/500
# 336/336 - 3s - loss: 2.9434 - accuracy: 0.2261 - 3s/epoch - 8ms/step
# Epoch 213/500
# 336/336 - 3s - loss: 2.9419 - accuracy: 0.2310 - 3s/epoch - 8ms/step
# Epoch 214/500
# 336/336 - 3s - loss: 2.9443 - accuracy: 0.2293 - 3s/epoch - 8ms/step
# Epoch 215/500
# 336/336 - 3s - loss: 2.9315 - accuracy: 0.2314 - 3s/epoch - 8ms/step
# Epoch 216/500
# 336/336 - 3s - loss: 2.9177 - accuracy: 0.2335 - 3s/epoch - 8ms/step
# Epoch 217/500
# 336/336 - 3s - loss: 2.9229 - accuracy: 0.2299 - 3s/epoch - 8ms/step
# Epoch 218/500
# 336/336 - 3s - loss: 2.9418 - accuracy: 0.2302 - 3s/epoch - 8ms/step
# Epoch 219/500
# 336/336 - 3s - loss: 2.9062 - accuracy: 0.2374 - 3s/epoch - 8ms/step
# Epoch 220/500
# 336/336 - 3s - loss: 2.9335 - accuracy: 0.2310 - 3s/epoch - 8ms/step
# Epoch 221/500
# 336/336 - 3s - loss: 2.9038 - accuracy: 0.2336 - 3s/epoch - 9ms/step
# Epoch 222/500
# 336/336 - 3s - loss: 2.9119 - accuracy: 0.2339 - 3s/epoch - 8ms/step
# Epoch 223/500
# 336/336 - 3s - loss: 2.9052 - accuracy: 0.2341 - 3s/epoch - 8ms/step
# Epoch 224/500
# 336/336 - 3s - loss: 2.9046 - accuracy: 0.2324 - 3s/epoch - 8ms/step
# Epoch 225/500
# 336/336 - 3s - loss: 2.8880 - accuracy: 0.2378 - 3s/epoch - 9ms/step
# Epoch 226/500
# 336/336 - 3s - loss: 2.8902 - accuracy: 0.2315 - 3s/epoch - 9ms/step
# Epoch 227/500
# 336/336 - 3s - loss: 2.8906 - accuracy: 0.2348 - 3s/epoch - 9ms/step
# Epoch 228/500
# 336/336 - 3s - loss: 2.8886 - accuracy: 0.2416 - 3s/epoch - 8ms/step
# Epoch 229/500
# 336/336 - 3s - loss: 2.8737 - accuracy: 0.2397 - 3s/epoch - 8ms/step
# Epoch 230/500
# 336/336 - 3s - loss: 2.8709 - accuracy: 0.2377 - 3s/epoch - 9ms/step
# Epoch 231/500
# 336/336 - 3s - loss: 2.8736 - accuracy: 0.2438 - 3s/epoch - 9ms/step
# Epoch 232/500
# 336/336 - 3s - loss: 2.8598 - accuracy: 0.2391 - 3s/epoch - 8ms/step
# Epoch 233/500
# 336/336 - 3s - loss: 2.8570 - accuracy: 0.2394 - 3s/epoch - 9ms/step
# Epoch 234/500
# 336/336 - 3s - loss: 2.8646 - accuracy: 0.2403 - 3s/epoch - 8ms/step
# Epoch 235/500
# 336/336 - 3s - loss: 2.8711 - accuracy: 0.2387 - 3s/epoch - 8ms/step
# Epoch 236/500
# 336/336 - 3s - loss: 2.8550 - accuracy: 0.2434 - 3s/epoch - 8ms/step
# Epoch 237/500
# 336/336 - 3s - loss: 2.8457 - accuracy: 0.2408 - 3s/epoch - 8ms/step
# Epoch 238/500
# 336/336 - 3s - loss: 2.8544 - accuracy: 0.2465 - 3s/epoch - 8ms/step
# Epoch 239/500
# 336/336 - 3s - loss: 2.8485 - accuracy: 0.2401 - 3s/epoch - 8ms/step
# Epoch 240/500
# 336/336 - 3s - loss: 2.8493 - accuracy: 0.2461 - 3s/epoch - 8ms/step
# Epoch 241/500
# 336/336 - 3s - loss: 2.8425 - accuracy: 0.2393 - 3s/epoch - 8ms/step
# Epoch 242/500
# 336/336 - 3s - loss: 2.8363 - accuracy: 0.2469 - 3s/epoch - 8ms/step
# Epoch 243/500
# 336/336 - 3s - loss: 2.8215 - accuracy: 0.2491 - 3s/epoch - 8ms/step
# Epoch 244/500
# 336/336 - 3s - loss: 2.8330 - accuracy: 0.2473 - 3s/epoch - 8ms/step
# Epoch 245/500
# 336/336 - 3s - loss: 2.8296 - accuracy: 0.2506 - 3s/epoch - 8ms/step
# Epoch 246/500
# 336/336 - 3s - loss: 2.8162 - accuracy: 0.2482 - 3s/epoch - 8ms/step
# Epoch 247/500
# 336/336 - 3s - loss: 2.8269 - accuracy: 0.2458 - 3s/epoch - 8ms/step
# Epoch 248/500
# 336/336 - 3s - loss: 2.8015 - accuracy: 0.2493 - 3s/epoch - 8ms/step
# Epoch 249/500
# 336/336 - 3s - loss: 2.8142 - accuracy: 0.2499 - 3s/epoch - 8ms/step
# Epoch 250/500
# 336/336 - 3s - loss: 2.8124 - accuracy: 0.2521 - 3s/epoch - 8ms/step
# Epoch 251/500
# 336/336 - 3s - loss: 2.8127 - accuracy: 0.2518 - 3s/epoch - 8ms/step
# Epoch 252/500
# 336/336 - 3s - loss: 2.8103 - accuracy: 0.2465 - 3s/epoch - 8ms/step
# Epoch 253/500
# 336/336 - 3s - loss: 2.7973 - accuracy: 0.2501 - 3s/epoch - 8ms/step
# Epoch 254/500
# 336/336 - 3s - loss: 2.7935 - accuracy: 0.2504 - 3s/epoch - 8ms/step
# Epoch 255/500
# 336/336 - 3s - loss: 2.7941 - accuracy: 0.2520 - 3s/epoch - 8ms/step
# Epoch 256/500
# 336/336 - 3s - loss: 2.7918 - accuracy: 0.2538 - 3s/epoch - 8ms/step
# Epoch 257/500
# 336/336 - 3s - loss: 2.7774 - accuracy: 0.2537 - 3s/epoch - 8ms/step
# Epoch 258/500
# 336/336 - 3s - loss: 2.7754 - accuracy: 0.2498 - 3s/epoch - 9ms/step
# Epoch 259/500
# 336/336 - 3s - loss: 2.7757 - accuracy: 0.2542 - 3s/epoch - 8ms/step
# Epoch 260/500
# 336/336 - 3s - loss: 2.7796 - accuracy: 0.2509 - 3s/epoch - 8ms/step
# Epoch 261/500
# 336/336 - 3s - loss: 2.7792 - accuracy: 0.2527 - 3s/epoch - 8ms/step
# Epoch 262/500
# 336/336 - 3s - loss: 2.7823 - accuracy: 0.2535 - 3s/epoch - 8ms/step
# Epoch 263/500
# 336/336 - 3s - loss: 2.7864 - accuracy: 0.2486 - 3s/epoch - 8ms/step
# Epoch 264/500
# 336/336 - 3s - loss: 2.7609 - accuracy: 0.2560 - 3s/epoch - 8ms/step
# Epoch 265/500
# 336/336 - 3s - loss: 2.7610 - accuracy: 0.2567 - 3s/epoch - 9ms/step
# Epoch 266/500
# 336/336 - 3s - loss: 2.7427 - accuracy: 0.2584 - 3s/epoch - 9ms/step
# Epoch 267/500
# 336/336 - 3s - loss: 2.7435 - accuracy: 0.2592 - 3s/epoch - 8ms/step
# Epoch 268/500
# 336/336 - 3s - loss: 2.7618 - accuracy: 0.2572 - 3s/epoch - 8ms/step
# Epoch 269/500
# 336/336 - 3s - loss: 2.7476 - accuracy: 0.2618 - 3s/epoch - 8ms/step
# Epoch 270/500
# 336/336 - 3s - loss: 2.7293 - accuracy: 0.2610 - 3s/epoch - 8ms/step
# Epoch 271/500
# 336/336 - 3s - loss: 2.7574 - accuracy: 0.2589 - 3s/epoch - 8ms/step
# Epoch 272/500
# 336/336 - 3s - loss: 2.7486 - accuracy: 0.2543 - 3s/epoch - 8ms/step
# Epoch 273/500
# 336/336 - 3s - loss: 2.7350 - accuracy: 0.2629 - 3s/epoch - 8ms/step
# Epoch 274/500
# 336/336 - 3s - loss: 2.7317 - accuracy: 0.2632 - 3s/epoch - 8ms/step
# Epoch 275/500
# 336/336 - 3s - loss: 2.7367 - accuracy: 0.2603 - 3s/epoch - 8ms/step
# Epoch 276/500
# 336/336 - 3s - loss: 2.7314 - accuracy: 0.2589 - 3s/epoch - 9ms/step
# Epoch 277/500
# 336/336 - 3s - loss: 2.7427 - accuracy: 0.2586 - 3s/epoch - 9ms/step
# Epoch 278/500
# 336/336 - 3s - loss: 2.7351 - accuracy: 0.2609 - 3s/epoch - 8ms/step
# Epoch 279/500
# 336/336 - 3s - loss: 2.7025 - accuracy: 0.2652 - 3s/epoch - 8ms/step
# Epoch 280/500
# 336/336 - 3s - loss: 2.7141 - accuracy: 0.2673 - 3s/epoch - 8ms/step
# Epoch 281/500
# 336/336 - 3s - loss: 2.7108 - accuracy: 0.2639 - 3s/epoch - 8ms/step
# Epoch 282/500
# 336/336 - 3s - loss: 2.7073 - accuracy: 0.2691 - 3s/epoch - 8ms/step
# Epoch 283/500
# 336/336 - 3s - loss: 2.7079 - accuracy: 0.2692 - 3s/epoch - 8ms/step
# Epoch 284/500
# 336/336 - 3s - loss: 2.7143 - accuracy: 0.2712 - 3s/epoch - 8ms/step
# Epoch 285/500
# 336/336 - 3s - loss: 2.7147 - accuracy: 0.2650 - 3s/epoch - 9ms/step
# Epoch 286/500
# 336/336 - 4s - loss: 2.6902 - accuracy: 0.2716 - 4s/epoch - 10ms/step
# Epoch 287/500
# 336/336 - 3s - loss: 2.6951 - accuracy: 0.2703 - 3s/epoch - 9ms/step
# Epoch 288/500
# 336/336 - 3s - loss: 2.6870 - accuracy: 0.2688 - 3s/epoch - 8ms/step
# Epoch 289/500
# 336/336 - 3s - loss: 2.6823 - accuracy: 0.2666 - 3s/epoch - 8ms/step
# Epoch 290/500
# 336/336 - 3s - loss: 2.6813 - accuracy: 0.2645 - 3s/epoch - 8ms/step
# Epoch 291/500
# 336/336 - 3s - loss: 2.6759 - accuracy: 0.2720 - 3s/epoch - 8ms/step
# Epoch 292/500
# 336/336 - 3s - loss: 2.6763 - accuracy: 0.2731 - 3s/epoch - 8ms/step
# Epoch 293/500
# 336/336 - 4s - loss: 2.6883 - accuracy: 0.2716 - 4s/epoch - 12ms/step
# Epoch 294/500
# 336/336 - 4s - loss: 2.6785 - accuracy: 0.2731 - 4s/epoch - 13ms/step
# Epoch 295/500
# 336/336 - 3s - loss: 2.6745 - accuracy: 0.2683 - 3s/epoch - 10ms/step
# Epoch 296/500
# 336/336 - 3s - loss: 2.6596 - accuracy: 0.2766 - 3s/epoch - 10ms/step
# Epoch 297/500
# 336/336 - 3s - loss: 2.6756 - accuracy: 0.2731 - 3s/epoch - 10ms/step
# Epoch 298/500
# 336/336 - 4s - loss: 2.6619 - accuracy: 0.2757 - 4s/epoch - 13ms/step
# Epoch 299/500
# 336/336 - 5s - loss: 2.6634 - accuracy: 0.2714 - 5s/epoch - 14ms/step
# Epoch 300/500
# 336/336 - 5s - loss: 2.6563 - accuracy: 0.2756 - 5s/epoch - 16ms/step
# Epoch 301/500
# 336/336 - 4s - loss: 2.6852 - accuracy: 0.2719 - 4s/epoch - 13ms/step
# Epoch 302/500
# 336/336 - 5s - loss: 2.6617 - accuracy: 0.2723 - 5s/epoch - 15ms/step
# Epoch 303/500
# 336/336 - 5s - loss: 2.6543 - accuracy: 0.2737 - 5s/epoch - 14ms/step
# Epoch 304/500
# 336/336 - 4s - loss: 2.6376 - accuracy: 0.2792 - 4s/epoch - 13ms/step
# Epoch 305/500
# 336/336 - 4s - loss: 2.6502 - accuracy: 0.2740 - 4s/epoch - 11ms/step
# Epoch 306/500
# 336/336 - 3s - loss: 2.6298 - accuracy: 0.2814 - 3s/epoch - 10ms/step
# Epoch 307/500
# 336/336 - 4s - loss: 2.6600 - accuracy: 0.2785 - 4s/epoch - 12ms/step
# Epoch 308/500
# 336/336 - 4s - loss: 2.6336 - accuracy: 0.2757 - 4s/epoch - 12ms/step
# Epoch 309/500
# 336/336 - 3s - loss: 2.6696 - accuracy: 0.2701 - 3s/epoch - 10ms/step
# Epoch 310/500
# 336/336 - 4s - loss: 2.6326 - accuracy: 0.2777 - 4s/epoch - 11ms/step
# Epoch 311/500
# 336/336 - 3s - loss: 2.6338 - accuracy: 0.2774 - 3s/epoch - 10ms/step
# Epoch 312/500
# 336/336 - 3s - loss: 2.6086 - accuracy: 0.2849 - 3s/epoch - 10ms/step
# Epoch 313/500
# 336/336 - 3s - loss: 2.6258 - accuracy: 0.2795 - 3s/epoch - 9ms/step
# Epoch 314/500
# 336/336 - 3s - loss: 2.6129 - accuracy: 0.2843 - 3s/epoch - 9ms/step
# Epoch 315/500
# 336/336 - 3s - loss: 2.6371 - accuracy: 0.2682 - 3s/epoch - 9ms/step
# Epoch 316/500
# 336/336 - 3s - loss: 2.6153 - accuracy: 0.2806 - 3s/epoch - 8ms/step
# Epoch 317/500
# 336/336 - 3s - loss: 2.6311 - accuracy: 0.2782 - 3s/epoch - 8ms/step
# Epoch 318/500
# 336/336 - 3s - loss: 2.5949 - accuracy: 0.2878 - 3s/epoch - 10ms/step
# Epoch 319/500
# 336/336 - 5s - loss: 2.6052 - accuracy: 0.2816 - 5s/epoch - 14ms/step
# Epoch 320/500
# 336/336 - 4s - loss: 2.5989 - accuracy: 0.2856 - 4s/epoch - 13ms/step
# Epoch 321/500
# 336/336 - 4s - loss: 2.6006 - accuracy: 0.2796 - 4s/epoch - 13ms/step
# Epoch 322/500
# 336/336 - 5s - loss: 2.6225 - accuracy: 0.2801 - 5s/epoch - 15ms/step
# Epoch 323/500
# 336/336 - 4s - loss: 2.6010 - accuracy: 0.2859 - 4s/epoch - 12ms/step
# Epoch 324/500
# 336/336 - 4s - loss: 2.6012 - accuracy: 0.2822 - 4s/epoch - 12ms/step
# Epoch 325/500
# 336/336 - 4s - loss: 2.5994 - accuracy: 0.2829 - 4s/epoch - 12ms/step
# Epoch 326/500
# 336/336 - 4s - loss: 2.5999 - accuracy: 0.2843 - 4s/epoch - 12ms/step
# Epoch 327/500
# 336/336 - 4s - loss: 2.5879 - accuracy: 0.2865 - 4s/epoch - 11ms/step
# Epoch 328/500
# 336/336 - 3s - loss: 2.5995 - accuracy: 0.2883 - 3s/epoch - 10ms/step
# Epoch 329/500
# 336/336 - 3s - loss: 2.5860 - accuracy: 0.2852 - 3s/epoch - 9ms/step
# Epoch 330/500
# 336/336 - 3s - loss: 2.5698 - accuracy: 0.2872 - 3s/epoch - 9ms/step
# Epoch 331/500
# 336/336 - 3s - loss: 2.5788 - accuracy: 0.2910 - 3s/epoch - 9ms/step
# Epoch 332/500
# 336/336 - 3s - loss: 2.5722 - accuracy: 0.2908 - 3s/epoch - 9ms/step
# Epoch 333/500
# 336/336 - 3s - loss: 2.5714 - accuracy: 0.2883 - 3s/epoch - 10ms/step
# Epoch 334/500
# 336/336 - 3s - loss: 2.5618 - accuracy: 0.2876 - 3s/epoch - 10ms/step
# Epoch 335/500
# 336/336 - 3s - loss: 2.5586 - accuracy: 0.2956 - 3s/epoch - 9ms/step
# Epoch 336/500
# 336/336 - 3s - loss: 2.5753 - accuracy: 0.2863 - 3s/epoch - 10ms/step
# Epoch 337/500
# 336/336 - 3s - loss: 2.5697 - accuracy: 0.2839 - 3s/epoch - 9ms/step
# Epoch 338/500
# 336/336 - 3s - loss: 2.5630 - accuracy: 0.2903 - 3s/epoch - 9ms/step
# Epoch 339/500
# 336/336 - 3s - loss: 2.5662 - accuracy: 0.2917 - 3s/epoch - 9ms/step
# Epoch 340/500
# 336/336 - 3s - loss: 2.5595 - accuracy: 0.2896 - 3s/epoch - 8ms/step
# Epoch 341/500
# 336/336 - 3s - loss: 2.5625 - accuracy: 0.2907 - 3s/epoch - 8ms/step
# Epoch 342/500
# 336/336 - 3s - loss: 2.5496 - accuracy: 0.2948 - 3s/epoch - 8ms/step
# Epoch 343/500
# 336/336 - 3s - loss: 2.5396 - accuracy: 0.2948 - 3s/epoch - 8ms/step
# Epoch 344/500
# 336/336 - 3s - loss: 2.5431 - accuracy: 0.2936 - 3s/epoch - 8ms/step
# Epoch 345/500
# 336/336 - 3s - loss: 2.5347 - accuracy: 0.3015 - 3s/epoch - 8ms/step
# Epoch 346/500
# 336/336 - 3s - loss: 2.5409 - accuracy: 0.2957 - 3s/epoch - 8ms/step
# Epoch 347/500
# 336/336 - 3s - loss: 2.5400 - accuracy: 0.2899 - 3s/epoch - 8ms/step
# Epoch 348/500
# 336/336 - 3s - loss: 2.5355 - accuracy: 0.2986 - 3s/epoch - 9ms/step
# Epoch 349/500
# 336/336 - 3s - loss: 2.5509 - accuracy: 0.2940 - 3s/epoch - 8ms/step
# Epoch 350/500
# 336/336 - 3s - loss: 2.5278 - accuracy: 0.2969 - 3s/epoch - 8ms/step
# Epoch 351/500
# 336/336 - 4s - loss: 2.5372 - accuracy: 0.2968 - 4s/epoch - 11ms/step
# Epoch 352/500
# 336/336 - 4s - loss: 2.5307 - accuracy: 0.2934 - 4s/epoch - 11ms/step
# Epoch 353/500
# 336/336 - 4s - loss: 2.5240 - accuracy: 0.3026 - 4s/epoch - 11ms/step
# Epoch 354/500
# 336/336 - 3s - loss: 2.5113 - accuracy: 0.2999 - 3s/epoch - 10ms/step
# Epoch 355/500
# 336/336 - 3s - loss: 2.5106 - accuracy: 0.3001 - 3s/epoch - 9ms/step
# Epoch 356/500
# 336/336 - 3s - loss: 2.5221 - accuracy: 0.2996 - 3s/epoch - 9ms/step
# Epoch 357/500
# 336/336 - 3s - loss: 2.5361 - accuracy: 0.2954 - 3s/epoch - 8ms/step
# Epoch 358/500
# 336/336 - 3s - loss: 2.5147 - accuracy: 0.2945 - 3s/epoch - 9ms/step
# Epoch 359/500
# 336/336 - 3s - loss: 2.5233 - accuracy: 0.2982 - 3s/epoch - 10ms/step
# Epoch 360/500
# 336/336 - 3s - loss: 2.5036 - accuracy: 0.2989 - 3s/epoch - 10ms/step
# Epoch 361/500
# 336/336 - 3s - loss: 2.5089 - accuracy: 0.3014 - 3s/epoch - 10ms/step
# Epoch 362/500
# 336/336 - 3s - loss: 2.5030 - accuracy: 0.3023 - 3s/epoch - 9ms/step
# Epoch 363/500
# 336/336 - 3s - loss: 2.4955 - accuracy: 0.3002 - 3s/epoch - 9ms/step
# Epoch 364/500
# 336/336 - 4s - loss: 2.4888 - accuracy: 0.3071 - 4s/epoch - 11ms/step
# Epoch 365/500
# 336/336 - 3s - loss: 2.5027 - accuracy: 0.2994 - 3s/epoch - 10ms/step
# Epoch 366/500
# 336/336 - 3s - loss: 2.4985 - accuracy: 0.3042 - 3s/epoch - 9ms/step
# Epoch 367/500
# 336/336 - 3s - loss: 2.4941 - accuracy: 0.3019 - 3s/epoch - 9ms/step
# Epoch 368/500
# 336/336 - 3s - loss: 2.4837 - accuracy: 0.3052 - 3s/epoch - 10ms/step
# Epoch 369/500
# 336/336 - 4s - loss: 2.4935 - accuracy: 0.3046 - 4s/epoch - 11ms/step
# Epoch 370/500
# 336/336 - 3s - loss: 2.4638 - accuracy: 0.3077 - 3s/epoch - 10ms/step
# Epoch 371/500
# 336/336 - 3s - loss: 2.4786 - accuracy: 0.3063 - 3s/epoch - 10ms/step
# Epoch 372/500
# 336/336 - 3s - loss: 2.4764 - accuracy: 0.3031 - 3s/epoch - 9ms/step
# Epoch 373/500
# 336/336 - 3s - loss: 2.5193 - accuracy: 0.2988 - 3s/epoch - 9ms/step
# Epoch 374/500
# 336/336 - 3s - loss: 2.4771 - accuracy: 0.3042 - 3s/epoch - 9ms/step
# Epoch 375/500
# 336/336 - 3s - loss: 2.4967 - accuracy: 0.3053 - 3s/epoch - 9ms/step
# Epoch 376/500
# 336/336 - 3s - loss: 2.4693 - accuracy: 0.3048 - 3s/epoch - 9ms/step
# Epoch 377/500
# 336/336 - 3s - loss: 2.4765 - accuracy: 0.3032 - 3s/epoch - 9ms/step
# Epoch 378/500
# 336/336 - 3s - loss: 2.4493 - accuracy: 0.3132 - 3s/epoch - 9ms/step
# Epoch 379/500
# 336/336 - 3s - loss: 2.4677 - accuracy: 0.3076 - 3s/epoch - 8ms/step
# Epoch 380/500
# 336/336 - 3s - loss: 2.4612 - accuracy: 0.3078 - 3s/epoch - 8ms/step
# Epoch 381/500
# 336/336 - 3s - loss: 2.4586 - accuracy: 0.3084 - 3s/epoch - 9ms/step
# Epoch 382/500
# 336/336 - 3s - loss: 2.4557 - accuracy: 0.3102 - 3s/epoch - 10ms/step
# Epoch 383/500
# 336/336 - 4s - loss: 2.4582 - accuracy: 0.3102 - 4s/epoch - 11ms/step
# Epoch 384/500
# 336/336 - 4s - loss: 2.4518 - accuracy: 0.3143 - 4s/epoch - 10ms/step
# Epoch 385/500
# 336/336 - 3s - loss: 2.4781 - accuracy: 0.3083 - 3s/epoch - 9ms/step
# Epoch 386/500
# 336/336 - 3s - loss: 2.4645 - accuracy: 0.3065 - 3s/epoch - 9ms/step
# Epoch 387/500
# 336/336 - 3s - loss: 2.4710 - accuracy: 0.3091 - 3s/epoch - 9ms/step
# Epoch 388/500
# 336/336 - 3s - loss: 2.4931 - accuracy: 0.3024 - 3s/epoch - 8ms/step
# Epoch 389/500
# 336/336 - 3s - loss: 2.4225 - accuracy: 0.3136 - 3s/epoch - 9ms/step
# Epoch 390/500
# 336/336 - 3s - loss: 2.4435 - accuracy: 0.3091 - 3s/epoch - 9ms/step
# Epoch 391/500
# 336/336 - 3s - loss: 2.4183 - accuracy: 0.3158 - 3s/epoch - 9ms/step
# Epoch 392/500
# 336/336 - 3s - loss: 2.4355 - accuracy: 0.3151 - 3s/epoch - 9ms/step
# Epoch 393/500
# 336/336 - 3s - loss: 2.4191 - accuracy: 0.3146 - 3s/epoch - 8ms/step
# Epoch 394/500
# 336/336 - 3s - loss: 2.4185 - accuracy: 0.3162 - 3s/epoch - 9ms/step
# Epoch 395/500
# 336/336 - 4s - loss: 2.4436 - accuracy: 0.3139 - 4s/epoch - 11ms/step
# Epoch 396/500
# 336/336 - 4s - loss: 2.4596 - accuracy: 0.3087 - 4s/epoch - 11ms/step
# Epoch 397/500
# 336/336 - 3s - loss: 2.4142 - accuracy: 0.3185 - 3s/epoch - 9ms/step
# Epoch 398/500
# 336/336 - 3s - loss: 2.4338 - accuracy: 0.3145 - 3s/epoch - 9ms/step
# Epoch 399/500
# 336/336 - 3s - loss: 2.4083 - accuracy: 0.3205 - 3s/epoch - 9ms/step
# Epoch 400/500
# 336/336 - 3s - loss: 2.4268 - accuracy: 0.3137 - 3s/epoch - 8ms/step
# Epoch 401/500
# 336/336 - 3s - loss: 2.4031 - accuracy: 0.3194 - 3s/epoch - 8ms/step
# Epoch 402/500
# 336/336 - 3s - loss: 2.4228 - accuracy: 0.3155 - 3s/epoch - 8ms/step
# Epoch 403/500
# 336/336 - 3s - loss: 2.4239 - accuracy: 0.3124 - 3s/epoch - 8ms/step
# Epoch 404/500
# 336/336 - 3s - loss: 2.4300 - accuracy: 0.3106 - 3s/epoch - 9ms/step
# Epoch 405/500
# 336/336 - 3s - loss: 2.3948 - accuracy: 0.3166 - 3s/epoch - 9ms/step
# Epoch 406/500
# 336/336 - 3s - loss: 2.4001 - accuracy: 0.3197 - 3s/epoch - 8ms/step
# Epoch 407/500
# 336/336 - 3s - loss: 2.4081 - accuracy: 0.3159 - 3s/epoch - 8ms/step
# Epoch 408/500
# 336/336 - 3s - loss: 2.4073 - accuracy: 0.3146 - 3s/epoch - 8ms/step
# Epoch 409/500
# 336/336 - 3s - loss: 2.4077 - accuracy: 0.3136 - 3s/epoch - 8ms/step
# Epoch 410/500
# 336/336 - 3s - loss: 2.4114 - accuracy: 0.3186 - 3s/epoch - 8ms/step
# Epoch 411/500
# 336/336 - 3s - loss: 2.3861 - accuracy: 0.3220 - 3s/epoch - 8ms/step
# Epoch 412/500
# 336/336 - 3s - loss: 2.4032 - accuracy: 0.3165 - 3s/epoch - 9ms/step
# Epoch 413/500
# 336/336 - 3s - loss: 2.4029 - accuracy: 0.3188 - 3s/epoch - 8ms/step
# Epoch 414/500
# 336/336 - 3s - loss: 2.3783 - accuracy: 0.3226 - 3s/epoch - 8ms/step
# Epoch 415/500
# 336/336 - 3s - loss: 2.3784 - accuracy: 0.3241 - 3s/epoch - 8ms/step
# Epoch 416/500
# 336/336 - 3s - loss: 2.3947 - accuracy: 0.3212 - 3s/epoch - 8ms/step
# Epoch 417/500
# 336/336 - 3s - loss: 2.3955 - accuracy: 0.3216 - 3s/epoch - 8ms/step
# Epoch 418/500
# 336/336 - 3s - loss: 2.3973 - accuracy: 0.3150 - 3s/epoch - 8ms/step
# Epoch 419/500
# 336/336 - 3s - loss: 2.3881 - accuracy: 0.3182 - 3s/epoch - 8ms/step
# Epoch 420/500
# 336/336 - 3s - loss: 2.3923 - accuracy: 0.3183 - 3s/epoch - 8ms/step
# Epoch 421/500
# 336/336 - 3s - loss: 2.3732 - accuracy: 0.3196 - 3s/epoch - 8ms/step
# Epoch 422/500
# 336/336 - 3s - loss: 2.3682 - accuracy: 0.3268 - 3s/epoch - 8ms/step
# Epoch 423/500
# 336/336 - 3s - loss: 2.3608 - accuracy: 0.3281 - 3s/epoch - 8ms/step
# Epoch 424/500
# 336/336 - 3s - loss: 2.3891 - accuracy: 0.3220 - 3s/epoch - 8ms/step
# Epoch 425/500
# 336/336 - 3s - loss: 2.3585 - accuracy: 0.3244 - 3s/epoch - 8ms/step
# Epoch 426/500
# 336/336 - 3s - loss: 2.3714 - accuracy: 0.3241 - 3s/epoch - 8ms/step
# Epoch 427/500
# 336/336 - 3s - loss: 2.3656 - accuracy: 0.3252 - 3s/epoch - 8ms/step
# Epoch 428/500
# 336/336 - 3s - loss: 2.3981 - accuracy: 0.3202 - 3s/epoch - 8ms/step
# Epoch 429/500
# 336/336 - 3s - loss: 2.3533 - accuracy: 0.3255 - 3s/epoch - 9ms/step
# Epoch 430/500
# 336/336 - 3s - loss: 2.3426 - accuracy: 0.3286 - 3s/epoch - 9ms/step
# Epoch 431/500
# 336/336 - 3s - loss: 2.3888 - accuracy: 0.3202 - 3s/epoch - 8ms/step
# Epoch 432/500
# 336/336 - 3s - loss: 2.3491 - accuracy: 0.3284 - 3s/epoch - 8ms/step
# Epoch 433/500
# 336/336 - 3s - loss: 2.3453 - accuracy: 0.3284 - 3s/epoch - 8ms/step
# Epoch 434/500
# 336/336 - 3s - loss: 2.3534 - accuracy: 0.3290 - 3s/epoch - 8ms/step
# Epoch 435/500
# 336/336 - 3s - loss: 2.3407 - accuracy: 0.3358 - 3s/epoch - 8ms/step
# Epoch 436/500
# 336/336 - 3s - loss: 2.3514 - accuracy: 0.3258 - 3s/epoch - 8ms/step
# Epoch 437/500
# 336/336 - 3s - loss: 2.3406 - accuracy: 0.3336 - 3s/epoch - 9ms/step
# Epoch 438/500
# 336/336 - 3s - loss: 2.3387 - accuracy: 0.3292 - 3s/epoch - 8ms/step
# Epoch 439/500
# 336/336 - 3s - loss: 2.3574 - accuracy: 0.3312 - 3s/epoch - 8ms/step
# Epoch 440/500
# 336/336 - 3s - loss: 2.3320 - accuracy: 0.3338 - 3s/epoch - 8ms/step
# Epoch 441/500
# 336/336 - 3s - loss: 2.3336 - accuracy: 0.3320 - 3s/epoch - 8ms/step
# Epoch 442/500
# 336/336 - 3s - loss: 2.3328 - accuracy: 0.3335 - 3s/epoch - 8ms/step
# Epoch 443/500
# 336/336 - 3s - loss: 2.3476 - accuracy: 0.3297 - 3s/epoch - 8ms/step
# Epoch 444/500
# 336/336 - 3s - loss: 2.3288 - accuracy: 0.3334 - 3s/epoch - 8ms/step
# Epoch 445/500
# 336/336 - 3s - loss: 2.3311 - accuracy: 0.3306 - 3s/epoch - 8ms/step
# Epoch 446/500
# 336/336 - 3s - loss: 2.3239 - accuracy: 0.3369 - 3s/epoch - 8ms/step
# Epoch 447/500
# 336/336 - 3s - loss: 2.3383 - accuracy: 0.3316 - 3s/epoch - 8ms/step
# Epoch 448/500
# 336/336 - 3s - loss: 2.3332 - accuracy: 0.3315 - 3s/epoch - 8ms/step
# Epoch 449/500
# 336/336 - 3s - loss: 2.3254 - accuracy: 0.3354 - 3s/epoch - 8ms/step
# Epoch 450/500
# 336/336 - 3s - loss: 2.3325 - accuracy: 0.3298 - 3s/epoch - 8ms/step
# Epoch 451/500
# 336/336 - 3s - loss: 2.3124 - accuracy: 0.3401 - 3s/epoch - 8ms/step
# Epoch 452/500
# 336/336 - 3s - loss: 2.3199 - accuracy: 0.3393 - 3s/epoch - 8ms/step
# Epoch 453/500
# 336/336 - 3s - loss: 2.3084 - accuracy: 0.3351 - 3s/epoch - 8ms/step
# Epoch 454/500
# 336/336 - 3s - loss: 2.3167 - accuracy: 0.3358 - 3s/epoch - 8ms/step
# Epoch 455/500
# 336/336 - 3s - loss: 2.3030 - accuracy: 0.3424 - 3s/epoch - 8ms/step
# Epoch 456/500
# 336/336 - 3s - loss: 2.3281 - accuracy: 0.3351 - 3s/epoch - 8ms/step
# Epoch 457/500
# 336/336 - 3s - loss: 2.2976 - accuracy: 0.3409 - 3s/epoch - 8ms/step
# Epoch 458/500
# 336/336 - 3s - loss: 2.3077 - accuracy: 0.3378 - 3s/epoch - 8ms/step
# Epoch 459/500
# 336/336 - 3s - loss: 2.2922 - accuracy: 0.3425 - 3s/epoch - 8ms/step
# Epoch 460/500
# 336/336 - 3s - loss: 2.2986 - accuracy: 0.3392 - 3s/epoch - 8ms/step
# Epoch 461/500
# 336/336 - 3s - loss: 2.3165 - accuracy: 0.3400 - 3s/epoch - 9ms/step
# Epoch 462/500
# 336/336 - 3s - loss: 2.2928 - accuracy: 0.3368 - 3s/epoch - 9ms/step
# Epoch 463/500
# 336/336 - 3s - loss: 2.3218 - accuracy: 0.3366 - 3s/epoch - 8ms/step
# Epoch 464/500
# 336/336 - 3s - loss: 2.2949 - accuracy: 0.3406 - 3s/epoch - 8ms/step
# Epoch 465/500
# 336/336 - 3s - loss: 2.3093 - accuracy: 0.3376 - 3s/epoch - 8ms/step
# Epoch 466/500
# 336/336 - 3s - loss: 2.2904 - accuracy: 0.3406 - 3s/epoch - 8ms/step
# Epoch 467/500
# 336/336 - 3s - loss: 2.2881 - accuracy: 0.3440 - 3s/epoch - 8ms/step
# Epoch 468/500
# 336/336 - 3s - loss: 2.3067 - accuracy: 0.3379 - 3s/epoch - 8ms/step
# Epoch 469/500
# 336/336 - 3s - loss: 2.3624 - accuracy: 0.3319 - 3s/epoch - 8ms/step
# Epoch 470/500
# 336/336 - 3s - loss: 2.2765 - accuracy: 0.3413 - 3s/epoch - 8ms/step
# Epoch 471/500
# 336/336 - 3s - loss: 2.2629 - accuracy: 0.3460 - 3s/epoch - 8ms/step
# Epoch 472/500
# 336/336 - 3s - loss: 2.2643 - accuracy: 0.3444 - 3s/epoch - 8ms/step
# Epoch 473/500
# 336/336 - 3s - loss: 2.2854 - accuracy: 0.3385 - 3s/epoch - 9ms/step
# Epoch 474/500
# 336/336 - 3s - loss: 2.2799 - accuracy: 0.3393 - 3s/epoch - 8ms/step
# Epoch 475/500
# 336/336 - 3s - loss: 2.2662 - accuracy: 0.3424 - 3s/epoch - 9ms/step
# Epoch 476/500
# 336/336 - 3s - loss: 2.2706 - accuracy: 0.3461 - 3s/epoch - 9ms/step
# Epoch 477/500
# 336/336 - 3s - loss: 2.2784 - accuracy: 0.3455 - 3s/epoch - 9ms/step
# Epoch 478/500
# 336/336 - 3s - loss: 2.2686 - accuracy: 0.3420 - 3s/epoch - 8ms/step
# Epoch 479/500
# 336/336 - 3s - loss: 2.2555 - accuracy: 0.3486 - 3s/epoch - 8ms/step
# Epoch 480/500
# 336/336 - 3s - loss: 2.2587 - accuracy: 0.3461 - 3s/epoch - 8ms/step
# Epoch 481/500
# 336/336 - 3s - loss: 2.2792 - accuracy: 0.3460 - 3s/epoch - 9ms/step
# Epoch 482/500
# 336/336 - 3s - loss: 2.2770 - accuracy: 0.3476 - 3s/epoch - 8ms/step
# Epoch 483/500
# 336/336 - 3s - loss: 2.2610 - accuracy: 0.3389 - 3s/epoch - 8ms/step
# Epoch 484/500
# 336/336 - 3s - loss: 2.2797 - accuracy: 0.3432 - 3s/epoch - 8ms/step
# Epoch 485/500
# 336/336 - 3s - loss: 2.2572 - accuracy: 0.3500 - 3s/epoch - 9ms/step
# Epoch 486/500
# 336/336 - 3s - loss: 2.2808 - accuracy: 0.3435 - 3s/epoch - 9ms/step
# Epoch 487/500
# 336/336 - 3s - loss: 2.2620 - accuracy: 0.3403 - 3s/epoch - 8ms/step
# Epoch 488/500
# 336/336 - 3s - loss: 2.2405 - accuracy: 0.3505 - 3s/epoch - 8ms/step
# Epoch 489/500
# 336/336 - 3s - loss: 2.2442 - accuracy: 0.3509 - 3s/epoch - 8ms/step
# Epoch 490/500
# 336/336 - 3s - loss: 2.2431 - accuracy: 0.3538 - 3s/epoch - 8ms/step
# Epoch 491/500
# 336/336 - 3s - loss: 2.2288 - accuracy: 0.3511 - 3s/epoch - 9ms/step
# Epoch 492/500
# 336/336 - 3s - loss: 2.2593 - accuracy: 0.3493 - 3s/epoch - 9ms/step
# Epoch 493/500
# 336/336 - 3s - loss: 2.2334 - accuracy: 0.3492 - 3s/epoch - 8ms/step
# Epoch 494/500
# 336/336 - 3s - loss: 2.2335 - accuracy: 0.3482 - 3s/epoch - 8ms/step
# Epoch 495/500
# 336/336 - 3s - loss: 2.2433 - accuracy: 0.3512 - 3s/epoch - 8ms/step
# Epoch 496/500
# 336/336 - 3s - loss: 2.2222 - accuracy: 0.3521 - 3s/epoch - 10ms/step
# Epoch 497/500
# 336/336 - 3s - loss: 2.2775 - accuracy: 0.3475 - 3s/epoch - 8ms/step
# Epoch 498/500
# 336/336 - 3s - loss: 2.2214 - accuracy: 0.3511 - 3s/epoch - 8ms/step
# Epoch 499/500
# 336/336 - 3s - loss: 2.2357 - accuracy: 0.3530 - 3s/epoch - 8ms/step
# Epoch 500/500
# 336/336 - 3s - loss: 2.2312 - accuracy: 0.3564 - 3s/epoch - 8ms/step

# %% [markdown]
# # Quantify our Trained Model

# %%
encoded_y_test = label_encoder.transform(y_test)
y_test_categorical = to_categorical(encoded_y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     371         try:
# --> 372             n_features = _num_features(X)
#     373         except TypeError as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py in _num_features(X)
#     233             message += f" with shape {X.shape}"
# --> 234             raise TypeError(message)
#     235         return X.shape[1]
#
# TypeError: Unable to find the number of features from X of type pandas.core.series.Series with shape (5294,)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_224/1542355979.py in <module>
# ----> 1 encoded_y_test = label_encoder.transform(y_test)
#       2 y_test_categorical = to_categorical(encoded_y_test)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py in transform(self, X)
#     928             Transformed input.
#     929         """
# --> 930         X_int, X_mask = self._transform(
#     931             X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan"
#     932         )
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py in _transform(self, X, handle_unknown, force_all_finite, warn_on_unknown)
#     121     ):
#     122         self._check_feature_names(X, reset=False)
# --> 123         self._check_n_features(X, reset=False)
#     124         X_list, n_samples, n_features = self._check_X(
#     125             X, force_all_finite=force_all_finite
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py in _check_n_features(self, X, reset)
#     373         except TypeError as e:
#     374             if not reset and hasattr(self, "n_features_in_"):
# --> 375                 raise ValueError(
#     376                     "X does not contain any features, but "
#     377                     f"{self.__class__.__name__} is expecting "
#
# ValueError: X does not contain any features, but OrdinalEncoder is expecting 1 features

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose = 2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_224/2886109848.py in <module>
# ----> 1 model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose = 2)
#       2 print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
#
# NameError: name 'y_test_categorical' is not defined

# %% [markdown]
# # Save the Model

# %%
filename = "../models/deep_learning_model.h5"
model.save(filename)
